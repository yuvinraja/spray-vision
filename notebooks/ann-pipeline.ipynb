# %%
# ─────────────────────────────────────────────────────────────
# Cell 1 ▸ Imports for ANN training
# ─────────────────────────────────────────────────────────────
import joblib
from keras import callbacks, layers, models, optimizers
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
# Out:
# TensorFlow version: 2.19.0

# %%
print(tf.config.list_physical_devices("GPU"))
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# ─────────────────────────────────────────────────────────────
#  Cell 2 ▸ Load & tidy the data
# ─────────────────────────────────────────────────────────────
csv_path = "data/processed/preprocessed_dataset.csv"
raw = pd.read_csv(csv_path)

# Harmonise column names
rename_map = {
    "Time_ms": "time",
    "Pc_bar": "chamb_pressure",
    "Tc_K": "cham_temp",
    "Pinj_bar": "injection_pres",
    "rho_kgm3": "density",
    "mu_Pas": "viscosity",
    "angle_shadow_deg": "angle_shadow",
    "len_shadow_L_D": "length_shadow",
    "angle_mie_deg": "angle_mie",
    "len_mie_L_D": "length_mie",
}
df = raw.rename(columns=rename_map)

INPUTS = ["time", "chamb_pressure", "cham_temp", "injection_pres", "density", "viscosity"]
TARGETS = ["angle_mie", "length_mie", "angle_shadow", "length_shadow"]

print("Data shape  :", df.shape)
display(df.head())
# Out:
# Data shape  : (726, 11)
#       run   time  chamb_pressure   cham_temp  injection_pres     density  \
# 0  ETH-01  0.000        55.03180  192.029519       98.864550  810.720228
# 1  ETH-01  0.025        55.00570  192.015831       98.874062  810.718262
# 2  ETH-01  0.050        55.00810  191.988228       98.907356  810.718443
# 3  ETH-01  0.075        55.01635  192.081988       98.855037  810.719065
# 4  ETH-01  0.100        55.01250  191.988000       98.878819  810.718775
#
#    viscosity  angle_shadow  length_shadow  angle_mie  length_mie
# 0   0.001879     16.694545      13.126559  12.937325   17.571262
# 1   0.001879     16.694545      13.126559  12.937325   17.571262
# 2   0.001879     16.694545      13.126559  12.937325   17.571262
# 3   0.001879     16.694545      13.126559  12.937325   17.571262
# 4   0.001879     16.694545      20.204667  12.937325   24.506565

# %%
from sklearn.model_selection import train_test_split

# ─────────────────────────────────────────────────────────────
#  Cell 3 ▸ Train-test split  (stratified by experimental run)
# ─────────────────────────────────────────────────────────────
X, y = df[INPUTS], df[TARGETS]
runs = df["run"]  # stratification label
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.20, random_state=42, stratify=runs)

print(f"Train: {X_tr.shape}   Test: {X_te.shape}")
# Out:
# Train: (580, 6)   Test: (146, 6)

# %%
# ─────────────────────────────────────────────────────────────
# Cell 4 ▸ Prepare scaled train and test data (reuse X_tr, y_tr, X_te, y_te)
# ─────────────────────────────────────────────────────────────
# Use the same train-test split as ML baselines (reuse your existing X_tr, y_tr, X_te, y_te)

# Scale input features
input_scaler = StandardScaler()
X_train_scaled = input_scaler.fit_transform(X_tr)
X_test_scaled = input_scaler.transform(X_te)

# Scale output targets
target_scaler = StandardScaler()
y_train_scaled = target_scaler.fit_transform(y_tr)
y_test_scaled = target_scaler.transform(y_te)

# Save scalers
joblib.dump(input_scaler, "models/ann_input_scaler.joblib")
joblib.dump(target_scaler, "models/ann_target_scaler.joblib")

print("Scaling completed. Shapes:", X_train_scaled.shape, y_train_scaled.shape)
# Out:
# Scaling completed. Shapes: (580, 6) (580, 4)

# %%
# ─────────────────────────────────────────────────────────────
# Cell 5 ▸ Build the ANN model architecture
# ─────────────────────────────────────────────────────────────
def build_deep_ann(input_dim, output_dim):
    model = models.Sequential(
        [
            layers.InputLayer(input_shape=(input_dim,)),
            layers.Dense(256, activation="relu"),
            layers.BatchNormalization(),
            layers.Dropout(0.4),
            layers.Dense(128, activation="relu"),
            layers.BatchNormalization(),
            layers.Dropout(0.3),
            layers.Dense(64, activation="relu"),
            layers.BatchNormalization(),
            layers.Dropout(0.2),
            layers.Dense(output_dim, activation="linear"),
        ]
    )

    model.compile(optimizer="adam", loss="mse", metrics=["mae"])
    return model


model = build_deep_ann(X_train_scaled.shape[1], y_train_scaled.shape[1])
model.summary()
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/core/input_layer.py:27: UserWarning: Argument `input_shape` is deprecated. Use `shape` instead.
#   warnings.warn(
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_3 (Dense)                 │ (None, 256)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,996 (175.77 KB)
#  Trainable params: 44,100 (172.27 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# ─────────────────────────────────────────────────────────────
# Cell 6 ▸ Train the ANN model with EarlyStopping
# ─────────────────────────────────────────────────────────────
early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10)

history = model.fit(
    X_train_scaled,
    y_train_scaled,
    validation_split=0.2,
    epochs=500,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    verbose="2",
)
# Out:
# Epoch 1/500
# 15/15 - 8s - 545ms/step - loss: 2.3214 - mae: 1.1992 - val_loss: 0.8218 - val_mae: 0.7679 - learning_rate: 1.0000e-03
# Epoch 2/500
# 15/15 - 0s - 8ms/step - loss: 1.3951 - mae: 0.9243 - val_loss: 0.7693 - val_mae: 0.7417 - learning_rate: 1.0000e-03
# Epoch 3/500
# 15/15 - 0s - 8ms/step - loss: 1.0165 - mae: 0.7931 - val_loss: 0.7341 - val_mae: 0.7217 - learning_rate: 1.0000e-03
# Epoch 4/500
# 15/15 - 0s - 8ms/step - loss: 0.9531 - mae: 0.7727 - val_loss: 0.6793 - val_mae: 0.6919 - learning_rate: 1.0000e-03
# Epoch 5/500
# 15/15 - 0s - 9ms/step - loss: 0.7438 - mae: 0.6935 - val_loss: 0.6307 - val_mae: 0.6654 - learning_rate: 1.0000e-03
# Epoch 6/500
# 15/15 - 0s - 8ms/step - loss: 0.6664 - mae: 0.6440 - val_loss: 0.5954 - val_mae: 0.6485 - learning_rate: 1.0000e-03
# Epoch 7/500
# 15/15 - 0s - 8ms/step - loss: 0.6121 - mae: 0.6167 - val_loss: 0.5577 - val_mae: 0.6259 - learning_rate: 1.0000e-03
# Epoch 8/500
# 15/15 - 0s - 8ms/step - loss: 0.5931 - mae: 0.5990 - val_loss: 0.5286 - val_mae: 0.6064 - learning_rate: 1.0000e-03
# Epoch 9/500
# 15/15 - 0s - 8ms/step - loss: 0.5468 - mae: 0.5839 - val_loss: 0.4984 - val_mae: 0.5857 - learning_rate: 1.0000e-03
# Epoch 10/500
# 15/15 - 0s - 8ms/step - loss: 0.5157 - mae: 0.5610 - val_loss: 0.4561 - val_mae: 0.5581 - learning_rate: 1.0000e-03
# Epoch 11/500
# 15/15 - 0s - 8ms/step - loss: 0.4778 - mae: 0.5478 - val_loss: 0.4282 - val_mae: 0.5384 - learning_rate: 1.0000e-03
# Epoch 12/500
# 15/15 - 0s - 8ms/step - loss: 0.4468 - mae: 0.5210 - val_loss: 0.3934 - val_mae: 0.5119 - learning_rate: 1.0000e-03
# Epoch 13/500
# 15/15 - 0s - 8ms/step - loss: 0.4359 - mae: 0.5156 - val_loss: 0.3769 - val_mae: 0.4945 - learning_rate: 1.0000e-03
# Epoch 14/500
# 15/15 - 0s - 8ms/step - loss: 0.4285 - mae: 0.5089 - val_loss: 0.3542 - val_mae: 0.4803 - learning_rate: 1.0000e-03
# Epoch 15/500
# 15/15 - 0s - 8ms/step - loss: 0.3856 - mae: 0.4850 - val_loss: 0.3263 - val_mae: 0.4566 - learning_rate: 1.0000e-03
# Epoch 16/500
# 15/15 - 0s - 8ms/step - loss: 0.3734 - mae: 0.4745 - val_loss: 0.3109 - val_mae: 0.4478 - learning_rate: 1.0000e-03
# Epoch 17/500
# 15/15 - 0s - 7ms/step - loss: 0.3544 - mae: 0.4722 - val_loss: 0.2875 - val_mae: 0.4273 - learning_rate: 1.0000e-03
# Epoch 18/500
# 15/15 - 0s - 8ms/step - loss: 0.3354 - mae: 0.4586 - val_loss: 0.2592 - val_mae: 0.4018 - learning_rate: 1.0000e-03
# Epoch 19/500
# 15/15 - 0s - 7ms/step - loss: 0.3233 - mae: 0.4440 - val_loss: 0.2335 - val_mae: 0.3817 - learning_rate: 1.0000e-03
# Epoch 20/500
# 15/15 - 0s - 8ms/step - loss: 0.3094 - mae: 0.4300 - val_loss: 0.2165 - val_mae: 0.3634 - learning_rate: 1.0000e-03
# Epoch 21/500
# 15/15 - 0s - 8ms/step - loss: 0.2837 - mae: 0.4126 - val_loss: 0.1958 - val_mae: 0.3479 - learning_rate: 1.0000e-03
# Epoch 22/500
# 15/15 - 0s - 10ms/step - loss: 0.2714 - mae: 0.4079 - val_loss: 0.1738 - val_mae: 0.3303 - learning_rate: 1.0000e-03
# Epoch 23/500
# 15/15 - 0s - 8ms/step - loss: 0.2940 - mae: 0.4192 - val_loss: 0.1631 - val_mae: 0.3175 - learning_rate: 1.0000e-03
# Epoch 24/500
# 15/15 - 0s - 7ms/step - loss: 0.2487 - mae: 0.3875 - val_loss: 0.1431 - val_mae: 0.2968 - learning_rate: 1.0000e-03
# Epoch 25/500
# 15/15 - 0s - 8ms/step - loss: 0.2537 - mae: 0.3966 - val_loss: 0.1258 - val_mae: 0.2765 - learning_rate: 1.0000e-03
# Epoch 26/500
# 15/15 - 0s - 8ms/step - loss: 0.2423 - mae: 0.3801 - val_loss: 0.1172 - val_mae: 0.2653 - learning_rate: 1.0000e-03
# Epoch 27/500
# 15/15 - 0s - 8ms/step - loss: 0.2421 - mae: 0.3853 - val_loss: 0.1020 - val_mae: 0.2443 - learning_rate: 1.0000e-03
# Epoch 28/500
# 15/15 - 0s - 8ms/step - loss: 0.2394 - mae: 0.3770 - val_loss: 0.0847 - val_mae: 0.2224 - learning_rate: 1.0000e-03
# Epoch 29/500
# 15/15 - 0s - 8ms/step - loss: 0.2164 - mae: 0.3618 - val_loss: 0.0808 - val_mae: 0.2214 - learning_rate: 1.0000e-03
# Epoch 30/500
# 15/15 - 0s - 8ms/step - loss: 0.2312 - mae: 0.3728 - val_loss: 0.0718 - val_mae: 0.2058 - learning_rate: 1.0000e-03
# Epoch 31/500
# 15/15 - 0s - 8ms/step - loss: 0.1927 - mae: 0.3413 - val_loss: 0.0567 - val_mae: 0.1803 - learning_rate: 1.0000e-03
# Epoch 32/500
# 15/15 - 0s - 8ms/step - loss: 0.2106 - mae: 0.3568 - val_loss: 0.0535 - val_mae: 0.1750 - learning_rate: 1.0000e-03
# Epoch 33/500
# 15/15 - 0s - 7ms/step - loss: 0.2068 - mae: 0.3522 - val_loss: 0.0458 - val_mae: 0.1637 - learning_rate: 1.0000e-03
# Epoch 34/500
# 15/15 - 0s - 8ms/step - loss: 0.1810 - mae: 0.3333 - val_loss: 0.0422 - val_mae: 0.1581 - learning_rate: 1.0000e-03
# Epoch 35/500
# 15/15 - 0s - 8ms/step - loss: 0.1936 - mae: 0.3347 - val_loss: 0.0360 - val_mae: 0.1458 - learning_rate: 1.0000e-03
# Epoch 36/500
# 15/15 - 0s - 8ms/step - loss: 0.1684 - mae: 0.3168 - val_loss: 0.0304 - val_mae: 0.1339 - learning_rate: 1.0000e-03
# Epoch 37/500
# 15/15 - 0s - 8ms/step - loss: 0.2025 - mae: 0.3440 - val_loss: 0.0276 - val_mae: 0.1265 - learning_rate: 1.0000e-03
# Epoch 38/500
# 15/15 - 0s - 12ms/step - loss: 0.1748 - mae: 0.3236 - val_loss: 0.0228 - val_mae: 0.1158 - learning_rate: 1.0000e-03
# Epoch 39/500
# 15/15 - 0s - 12ms/step - loss: 0.1662 - mae: 0.3174 - val_loss: 0.0218 - val_mae: 0.1128 - learning_rate: 1.0000e-03
# Epoch 40/500
# 15/15 - 0s - 11ms/step - loss: 0.1675 - mae: 0.3215 - val_loss: 0.0170 - val_mae: 0.0978 - learning_rate: 1.0000e-03
# Epoch 41/500
# 15/15 - 0s - 12ms/step - loss: 0.1532 - mae: 0.3075 - val_loss: 0.0173 - val_mae: 0.1008 - learning_rate: 1.0000e-03
# Epoch 42/500
# 15/15 - 0s - 11ms/step - loss: 0.1746 - mae: 0.3210 - val_loss: 0.0167 - val_mae: 0.0988 - learning_rate: 1.0000e-03
# Epoch 43/500
# 15/15 - 0s - 12ms/step - loss: 0.1577 - mae: 0.3071 - val_loss: 0.0181 - val_mae: 0.1029 - learning_rate: 1.0000e-03
# Epoch 44/500
# 15/15 - 0s - 12ms/step - loss: 0.1465 - mae: 0.2943 - val_loss: 0.0147 - val_mae: 0.0918 - learning_rate: 1.0000e-03
# Epoch 45/500
# 15/15 - 0s - 12ms/step - loss: 0.1430 - mae: 0.2923 - val_loss: 0.0131 - val_mae: 0.0865 - learning_rate: 1.0000e-03
# Epoch 46/500
# 15/15 - 0s - 10ms/step - loss: 0.1298 - mae: 0.2807 - val_loss: 0.0158 - val_mae: 0.0921 - learning_rate: 1.0000e-03
# Epoch 47/500
# 15/15 - 0s - 11ms/step - loss: 0.1249 - mae: 0.2781 - val_loss: 0.0156 - val_mae: 0.0908 - learning_rate: 1.0000e-03
# Epoch 48/500
# 15/15 - 0s - 12ms/step - loss: 0.1366 - mae: 0.2848 - val_loss: 0.0121 - val_mae: 0.0808 - learning_rate: 1.0000e-03
# Epoch 49/500
# 15/15 - 0s - 7ms/step - loss: 0.1308 - mae: 0.2789 - val_loss: 0.0131 - val_mae: 0.0837 - learning_rate: 1.0000e-03
# Epoch 50/500
# 15/15 - 0s - 7ms/step - loss: 0.1453 - mae: 0.3006 - val_loss: 0.0142 - val_mae: 0.0877 - learning_rate: 1.0000e-03
# Epoch 51/500
# 15/15 - 0s - 8ms/step - loss: 0.1358 - mae: 0.2881 - val_loss: 0.0154 - val_mae: 0.0914 - learning_rate: 1.0000e-03
# Epoch 52/500
# 15/15 - 0s - 7ms/step - loss: 0.1259 - mae: 0.2787 - val_loss: 0.0132 - val_mae: 0.0867 - learning_rate: 1.0000e-03
# Epoch 53/500
# 15/15 - 0s - 7ms/step - loss: 0.1325 - mae: 0.2856 - val_loss: 0.0137 - val_mae: 0.0875 - learning_rate: 1.0000e-03
# Epoch 54/500
# 15/15 - 0s - 7ms/step - loss: 0.1329 - mae: 0.2854 - val_loss: 0.0126 - val_mae: 0.0849 - learning_rate: 1.0000e-03
# Epoch 55/500
# 15/15 - 0s - 7ms/step - loss: 0.1292 - mae: 0.2751 - val_loss: 0.0132 - val_mae: 0.0874 - learning_rate: 1.0000e-03
# Epoch 56/500
# 15/15 - 0s - 7ms/step - loss: 0.1276 - mae: 0.2786 - val_loss: 0.0120 - val_mae: 0.0803 - learning_rate: 1.0000e-03
# Epoch 57/500
# 15/15 - 0s - 7ms/step - loss: 0.1222 - mae: 0.2708 - val_loss: 0.0119 - val_mae: 0.0811 - learning_rate: 1.0000e-03
# Epoch 58/500
# 15/15 - 0s - 7ms/step - loss: 0.1310 - mae: 0.2794 - val_loss: 0.0125 - val_mae: 0.0836 - learning_rate: 1.0000e-03
# Epoch 59/500
# 15/15 - 0s - 7ms/step - loss: 0.1367 - mae: 0.2854 - val_loss: 0.0120 - val_mae: 0.0817 - learning_rate: 1.0000e-03
# Epoch 60/500
# 15/15 - 0s - 8ms/step - loss: 0.1180 - mae: 0.2636 - val_loss: 0.0143 - val_mae: 0.0908 - learning_rate: 1.0000e-03
# Epoch 61/500
# 15/15 - 0s - 7ms/step - loss: 0.1105 - mae: 0.2610 - val_loss: 0.0112 - val_mae: 0.0819 - learning_rate: 1.0000e-03
# Epoch 62/500
# 15/15 - 0s - 7ms/step - loss: 0.1146 - mae: 0.2662 - val_loss: 0.0121 - val_mae: 0.0827 - learning_rate: 1.0000e-03
# Epoch 63/500
# 15/15 - 0s - 7ms/step - loss: 0.1163 - mae: 0.2633 - val_loss: 0.0105 - val_mae: 0.0774 - learning_rate: 1.0000e-03
# Epoch 64/500
# 15/15 - 0s - 7ms/step - loss: 0.1183 - mae: 0.2701 - val_loss: 0.0114 - val_mae: 0.0794 - learning_rate: 1.0000e-03
# Epoch 65/500
# 15/15 - 0s - 7ms/step - loss: 0.1202 - mae: 0.2691 - val_loss: 0.0136 - val_mae: 0.0868 - learning_rate: 1.0000e-03
# Epoch 66/500
# 15/15 - 0s - 7ms/step - loss: 0.1119 - mae: 0.2570 - val_loss: 0.0113 - val_mae: 0.0801 - learning_rate: 1.0000e-03
# Epoch 67/500
# 15/15 - 0s - 7ms/step - loss: 0.1062 - mae: 0.2533 - val_loss: 0.0108 - val_mae: 0.0777 - learning_rate: 1.0000e-03
# Epoch 68/500
# 15/15 - 0s - 7ms/step - loss: 0.1080 - mae: 0.2513 - val_loss: 0.0123 - val_mae: 0.0821 - learning_rate: 1.0000e-03
# Epoch 69/500
# 15/15 - 0s - 8ms/step - loss: 0.1058 - mae: 0.2527 - val_loss: 0.0118 - val_mae: 0.0803 - learning_rate: 1.0000e-03
# Epoch 70/500
# 15/15 - 0s - 7ms/step - loss: 0.0987 - mae: 0.2421 - val_loss: 0.0108 - val_mae: 0.0758 - learning_rate: 1.0000e-03
# Epoch 71/500
# 15/15 - 0s - 7ms/step - loss: 0.1285 - mae: 0.2782 - val_loss: 0.0135 - val_mae: 0.0875 - learning_rate: 1.0000e-03
# Epoch 72/500
# 15/15 - 0s - 7ms/step - loss: 0.0973 - mae: 0.2408 - val_loss: 0.0124 - val_mae: 0.0840 - learning_rate: 1.0000e-03
# Epoch 73/500
# 15/15 - 0s - 7ms/step - loss: 0.0952 - mae: 0.2373 - val_loss: 0.0121 - val_mae: 0.0832 - learning_rate: 1.0000e-03
# Epoch 74/500
# 15/15 - 0s - 7ms/step - loss: 0.1045 - mae: 0.2486 - val_loss: 0.0115 - val_mae: 0.0819 - learning_rate: 5.0000e-04
# Epoch 75/500
# 15/15 - 0s - 7ms/step - loss: 0.1007 - mae: 0.2440 - val_loss: 0.0117 - val_mae: 0.0843 - learning_rate: 5.0000e-04
# Epoch 76/500
# 15/15 - 0s - 7ms/step - loss: 0.1129 - mae: 0.2595 - val_loss: 0.0115 - val_mae: 0.0840 - learning_rate: 5.0000e-04
# Epoch 77/500
# 15/15 - 0s - 7ms/step - loss: 0.1183 - mae: 0.2619 - val_loss: 0.0105 - val_mae: 0.0807 - learning_rate: 5.0000e-04
# Epoch 78/500
# 15/15 - 0s - 8ms/step - loss: 0.0918 - mae: 0.2338 - val_loss: 0.0116 - val_mae: 0.0832 - learning_rate: 5.0000e-04
# Epoch 79/500
# 15/15 - 0s - 7ms/step - loss: 0.1138 - mae: 0.2571 - val_loss: 0.0118 - val_mae: 0.0816 - learning_rate: 5.0000e-04
# Epoch 80/500
# 15/15 - 0s - 7ms/step - loss: 0.1017 - mae: 0.2457 - val_loss: 0.0115 - val_mae: 0.0822 - learning_rate: 5.0000e-04
# Epoch 81/500
# 15/15 - 0s - 7ms/step - loss: 0.1142 - mae: 0.2596 - val_loss: 0.0110 - val_mae: 0.0790 - learning_rate: 5.0000e-04
# Epoch 82/500
# 15/15 - 0s - 8ms/step - loss: 0.0992 - mae: 0.2489 - val_loss: 0.0095 - val_mae: 0.0725 - learning_rate: 5.0000e-04
# Epoch 83/500
# 15/15 - 0s - 7ms/step - loss: 0.1164 - mae: 0.2637 - val_loss: 0.0094 - val_mae: 0.0724 - learning_rate: 5.0000e-04
# Epoch 84/500
# 15/15 - 0s - 7ms/step - loss: 0.1105 - mae: 0.2591 - val_loss: 0.0099 - val_mae: 0.0743 - learning_rate: 5.0000e-04
# Epoch 85/500
# 15/15 - 0s - 7ms/step - loss: 0.1168 - mae: 0.2571 - val_loss: 0.0099 - val_mae: 0.0758 - learning_rate: 5.0000e-04
# Epoch 86/500
# 15/15 - 0s - 7ms/step - loss: 0.0890 - mae: 0.2302 - val_loss: 0.0096 - val_mae: 0.0725 - learning_rate: 5.0000e-04
# Epoch 87/500
# 15/15 - 0s - 8ms/step - loss: 0.0883 - mae: 0.2324 - val_loss: 0.0091 - val_mae: 0.0703 - learning_rate: 5.0000e-04
# Epoch 88/500
# 15/15 - 0s - 7ms/step - loss: 0.1093 - mae: 0.2521 - val_loss: 0.0092 - val_mae: 0.0714 - learning_rate: 5.0000e-04
# Epoch 89/500
# 15/15 - 0s - 7ms/step - loss: 0.1035 - mae: 0.2490 - val_loss: 0.0102 - val_mae: 0.0763 - learning_rate: 5.0000e-04
# Epoch 90/500
# 15/15 - 0s - 7ms/step - loss: 0.0883 - mae: 0.2330 - val_loss: 0.0092 - val_mae: 0.0714 - learning_rate: 5.0000e-04
# Epoch 91/500
# 15/15 - 0s - 8ms/step - loss: 0.0858 - mae: 0.2233 - val_loss: 0.0088 - val_mae: 0.0690 - learning_rate: 5.0000e-04
# Epoch 92/500
# 15/15 - 0s - 7ms/step - loss: 0.1079 - mae: 0.2564 - val_loss: 0.0089 - val_mae: 0.0699 - learning_rate: 5.0000e-04
# Epoch 93/500
# 15/15 - 0s - 7ms/step - loss: 0.0960 - mae: 0.2403 - val_loss: 0.0088 - val_mae: 0.0701 - learning_rate: 5.0000e-04
# Epoch 94/500
# 15/15 - 0s - 7ms/step - loss: 0.1007 - mae: 0.2425 - val_loss: 0.0091 - val_mae: 0.0715 - learning_rate: 5.0000e-04
# Epoch 95/500
# 15/15 - 0s - 7ms/step - loss: 0.0993 - mae: 0.2479 - val_loss: 0.0089 - val_mae: 0.0703 - learning_rate: 5.0000e-04
# Epoch 96/500
# 15/15 - 0s - 8ms/step - loss: 0.0912 - mae: 0.2345 - val_loss: 0.0095 - val_mae: 0.0723 - learning_rate: 5.0000e-04
# Epoch 97/500
# 15/15 - 0s - 7ms/step - loss: 0.0908 - mae: 0.2328 - val_loss: 0.0097 - val_mae: 0.0751 - learning_rate: 5.0000e-04
# Epoch 98/500
# 15/15 - 0s - 7ms/step - loss: 0.1096 - mae: 0.2533 - val_loss: 0.0096 - val_mae: 0.0751 - learning_rate: 5.0000e-04
# Epoch 99/500
# 15/15 - 0s - 7ms/step - loss: 0.0948 - mae: 0.2426 - val_loss: 0.0098 - val_mae: 0.0756 - learning_rate: 5.0000e-04
# Epoch 100/500
# 15/15 - 0s - 7ms/step - loss: 0.0983 - mae: 0.2438 - val_loss: 0.0089 - val_mae: 0.0719 - learning_rate: 5.0000e-04
# Epoch 101/500
# 15/15 - 0s - 7ms/step - loss: 0.0959 - mae: 0.2426 - val_loss: 0.0095 - val_mae: 0.0744 - learning_rate: 5.0000e-04
# Epoch 102/500
# 15/15 - 0s - 8ms/step - loss: 0.0932 - mae: 0.2418 - val_loss: 0.0093 - val_mae: 0.0737 - learning_rate: 2.5000e-04
# Epoch 103/500
# 15/15 - 0s - 7ms/step - loss: 0.1041 - mae: 0.2473 - val_loss: 0.0092 - val_mae: 0.0728 - learning_rate: 2.5000e-04
# Epoch 104/500
# 15/15 - 0s - 11ms/step - loss: 0.0889 - mae: 0.2326 - val_loss: 0.0088 - val_mae: 0.0710 - learning_rate: 2.5000e-04
# Epoch 105/500
# 15/15 - 0s - 27ms/step - loss: 0.1032 - mae: 0.2444 - val_loss: 0.0089 - val_mae: 0.0713 - learning_rate: 2.5000e-04
# Epoch 106/500
# 15/15 - 0s - 15ms/step - loss: 0.0958 - mae: 0.2439 - val_loss: 0.0088 - val_mae: 0.0715 - learning_rate: 2.5000e-04
# Epoch 107/500
# 15/15 - 1s - 36ms/step - loss: 0.0951 - mae: 0.2442 - val_loss: 0.0096 - val_mae: 0.0749 - learning_rate: 2.5000e-04
# Epoch 108/500
# 15/15 - 0s - 15ms/step - loss: 0.0779 - mae: 0.2172 - val_loss: 0.0091 - val_mae: 0.0730 - learning_rate: 2.5000e-04
# Epoch 109/500
# 15/15 - 0s - 11ms/step - loss: 0.0833 - mae: 0.2220 - val_loss: 0.0089 - val_mae: 0.0724 - learning_rate: 2.5000e-04
# Epoch 110/500
# 15/15 - 0s - 21ms/step - loss: 0.0913 - mae: 0.2305 - val_loss: 0.0096 - val_mae: 0.0760 - learning_rate: 2.5000e-04
# Epoch 111/500
# 15/15 - 0s - 7ms/step - loss: 0.0933 - mae: 0.2354 - val_loss: 0.0096 - val_mae: 0.0756 - learning_rate: 2.5000e-04
# Epoch 112/500
# 15/15 - 0s - 8ms/step - loss: 0.0900 - mae: 0.2327 - val_loss: 0.0094 - val_mae: 0.0751 - learning_rate: 1.2500e-04
# Epoch 113/500
# 15/15 - 0s - 7ms/step - loss: 0.0923 - mae: 0.2349 - val_loss: 0.0094 - val_mae: 0.0745 - learning_rate: 1.2500e-04
# Epoch 114/500
# 15/15 - 0s - 7ms/step - loss: 0.0829 - mae: 0.2203 - val_loss: 0.0091 - val_mae: 0.0727 - learning_rate: 1.2500e-04
# Epoch 115/500
# 15/15 - 0s - 22ms/step - loss: 0.0974 - mae: 0.2406 - val_loss: 0.0091 - val_mae: 0.0724 - learning_rate: 1.2500e-04
# Epoch 116/500
# 15/15 - 0s - 26ms/step - loss: 0.0896 - mae: 0.2374 - val_loss: 0.0089 - val_mae: 0.0714 - learning_rate: 1.2500e-04
# Epoch 117/500
# 15/15 - 0s - 8ms/step - loss: 0.0839 - mae: 0.2244 - val_loss: 0.0086 - val_mae: 0.0703 - learning_rate: 1.2500e-04
# Epoch 118/500
# 15/15 - 0s - 7ms/step - loss: 0.0982 - mae: 0.2432 - val_loss: 0.0085 - val_mae: 0.0694 - learning_rate: 1.2500e-04
# Epoch 119/500
# 15/15 - 0s - 7ms/step - loss: 0.0849 - mae: 0.2303 - val_loss: 0.0083 - val_mae: 0.0682 - learning_rate: 1.2500e-04
# Epoch 120/500
# 15/15 - 0s - 8ms/step - loss: 0.0919 - mae: 0.2381 - val_loss: 0.0083 - val_mae: 0.0685 - learning_rate: 1.2500e-04
# Epoch 121/500
# 15/15 - 0s - 13ms/step - loss: 0.0916 - mae: 0.2342 - val_loss: 0.0083 - val_mae: 0.0687 - learning_rate: 1.2500e-04
# Epoch 122/500
# 15/15 - 0s - 10ms/step - loss: 0.0975 - mae: 0.2465 - val_loss: 0.0084 - val_mae: 0.0691 - learning_rate: 1.2500e-04
# Epoch 123/500
# 15/15 - 0s - 23ms/step - loss: 0.0925 - mae: 0.2372 - val_loss: 0.0083 - val_mae: 0.0684 - learning_rate: 1.2500e-04
# Epoch 124/500
# 15/15 - 0s - 10ms/step - loss: 0.0786 - mae: 0.2188 - val_loss: 0.0083 - val_mae: 0.0685 - learning_rate: 1.2500e-04
# Epoch 125/500
# 15/15 - 0s - 10ms/step - loss: 0.1039 - mae: 0.2494 - val_loss: 0.0082 - val_mae: 0.0674 - learning_rate: 1.2500e-04
# Epoch 126/500
# 15/15 - 0s - 11ms/step - loss: 0.0958 - mae: 0.2375 - val_loss: 0.0081 - val_mae: 0.0670 - learning_rate: 1.2500e-04
# Epoch 127/500
# 15/15 - 0s - 22ms/step - loss: 0.1084 - mae: 0.2531 - val_loss: 0.0083 - val_mae: 0.0682 - learning_rate: 1.2500e-04
# Epoch 128/500
# 15/15 - 0s - 12ms/step - loss: 0.0878 - mae: 0.2318 - val_loss: 0.0084 - val_mae: 0.0693 - learning_rate: 1.2500e-04
# Epoch 129/500
# 15/15 - 0s - 8ms/step - loss: 0.0994 - mae: 0.2429 - val_loss: 0.0086 - val_mae: 0.0709 - learning_rate: 1.2500e-04
# Epoch 130/500
# 15/15 - 0s - 7ms/step - loss: 0.0866 - mae: 0.2292 - val_loss: 0.0089 - val_mae: 0.0718 - learning_rate: 1.2500e-04
# Epoch 131/500
# 15/15 - 0s - 7ms/step - loss: 0.0878 - mae: 0.2296 - val_loss: 0.0087 - val_mae: 0.0709 - learning_rate: 1.2500e-04
# Epoch 132/500
# 15/15 - 0s - 7ms/step - loss: 0.1018 - mae: 0.2474 - val_loss: 0.0089 - val_mae: 0.0720 - learning_rate: 1.2500e-04
# Epoch 133/500
# 15/15 - 0s - 7ms/step - loss: 0.0931 - mae: 0.2416 - val_loss: 0.0087 - val_mae: 0.0705 - learning_rate: 1.2500e-04
# Epoch 134/500
# 15/15 - 0s - 7ms/step - loss: 0.1074 - mae: 0.2554 - val_loss: 0.0088 - val_mae: 0.0706 - learning_rate: 1.2500e-04
# Epoch 135/500
# 15/15 - 0s - 7ms/step - loss: 0.1042 - mae: 0.2528 - val_loss: 0.0088 - val_mae: 0.0709 - learning_rate: 1.2500e-04
# Epoch 136/500
# 15/15 - 0s - 7ms/step - loss: 0.1020 - mae: 0.2524 - val_loss: 0.0087 - val_mae: 0.0712 - learning_rate: 6.2500e-05
# Epoch 137/500
# 15/15 - 0s - 7ms/step - loss: 0.0804 - mae: 0.2216 - val_loss: 0.0086 - val_mae: 0.0709 - learning_rate: 6.2500e-05
# Epoch 138/500
# 15/15 - 0s - 8ms/step - loss: 0.0856 - mae: 0.2230 - val_loss: 0.0086 - val_mae: 0.0714 - learning_rate: 6.2500e-05
# Epoch 139/500
# 15/15 - 0s - 7ms/step - loss: 0.1013 - mae: 0.2454 - val_loss: 0.0087 - val_mae: 0.0719 - learning_rate: 6.2500e-05
# Epoch 140/500
# 15/15 - 0s - 7ms/step - loss: 0.0824 - mae: 0.2209 - val_loss: 0.0088 - val_mae: 0.0725 - learning_rate: 6.2500e-05
# Epoch 141/500
# 15/15 - 0s - 7ms/step - loss: 0.0835 - mae: 0.2311 - val_loss: 0.0086 - val_mae: 0.0713 - learning_rate: 6.2500e-05
# Epoch 142/500
# 15/15 - 0s - 7ms/step - loss: 0.0862 - mae: 0.2294 - val_loss: 0.0086 - val_mae: 0.0710 - learning_rate: 6.2500e-05
# Epoch 143/500
# 15/15 - 0s - 7ms/step - loss: 0.1050 - mae: 0.2485 - val_loss: 0.0086 - val_mae: 0.0709 - learning_rate: 6.2500e-05
# Epoch 144/500
# 15/15 - 0s - 7ms/step - loss: 0.0793 - mae: 0.2160 - val_loss: 0.0087 - val_mae: 0.0708 - learning_rate: 6.2500e-05
# Epoch 145/500
# 15/15 - 0s - 7ms/step - loss: 0.1006 - mae: 0.2454 - val_loss: 0.0086 - val_mae: 0.0706 - learning_rate: 6.2500e-05
# Epoch 146/500
# 15/15 - 0s - 7ms/step - loss: 0.0909 - mae: 0.2331 - val_loss: 0.0086 - val_mae: 0.0708 - learning_rate: 3.1250e-05
# Epoch 147/500
# 15/15 - 0s - 8ms/step - loss: 0.0922 - mae: 0.2390 - val_loss: 0.0087 - val_mae: 0.0708 - learning_rate: 3.1250e-05
# Epoch 148/500
# 15/15 - 0s - 7ms/step - loss: 0.0982 - mae: 0.2455 - val_loss: 0.0088 - val_mae: 0.0711 - learning_rate: 3.1250e-05
# Epoch 149/500
# 15/15 - 0s - 7ms/step - loss: 0.0977 - mae: 0.2405 - val_loss: 0.0087 - val_mae: 0.0706 - learning_rate: 3.1250e-05
# Epoch 150/500
# 15/15 - 0s - 7ms/step - loss: 0.0973 - mae: 0.2451 - val_loss: 0.0086 - val_mae: 0.0700 - learning_rate: 3.1250e-05
# Epoch 151/500
# 15/15 - 0s - 7ms/step - loss: 0.0830 - mae: 0.2264 - val_loss: 0.0085 - val_mae: 0.0698 - learning_rate: 3.1250e-05
# Epoch 152/500
# 15/15 - 0s - 7ms/step - loss: 0.0865 - mae: 0.2288 - val_loss: 0.0086 - val_mae: 0.0703 - learning_rate: 3.1250e-05
# Epoch 153/500
# 15/15 - 0s - 7ms/step - loss: 0.0837 - mae: 0.2261 - val_loss: 0.0087 - val_mae: 0.0707 - learning_rate: 3.1250e-05
# Epoch 154/500
# 15/15 - 0s - 7ms/step - loss: 0.1036 - mae: 0.2534 - val_loss: 0.0085 - val_mae: 0.0701 - learning_rate: 3.1250e-05
# Epoch 155/500
# 15/15 - 0s - 7ms/step - loss: 0.0939 - mae: 0.2421 - val_loss: 0.0086 - val_mae: 0.0706 - learning_rate: 3.1250e-05
# Epoch 156/500
# 15/15 - 0s - 8ms/step - loss: 0.1215 - mae: 0.2696 - val_loss: 0.0085 - val_mae: 0.0706 - learning_rate: 1.5625e-05

# %%
# ─────────────────────────────────────────────────────────────
# Cell 7 ▸ Evaluate the ANN model on the test set
# ─────────────────────────────────────────────────────────────

# Inverse transform predictions & evaluate on original scale
y_pred_scaled = model.predict(X_test_scaled)
y_pred = target_scaler.inverse_transform(y_pred_scaled)

r2_scores, mae_scores, mse_scores = [], [], []
for i, col in enumerate(y_te.columns):
    r2 = r2_score(y_te[col], y_pred[:, i])
    mae = mean_absolute_error(y_te[col], y_pred[:, i])
    mse = mean_squared_error(y_te[col], y_pred[:, i])
    r2_scores.append(r2)
    mae_scores.append(mae)
    mse_scores.append(mse)
    print(f"{col:>15}: R²={r2:.4f}, MAE={mae:.4f}, MSE={mse:.4f}")

print(f"\nOverall mean R²: {np.mean(r2_scores):.4f}")
print(f"Overall mean MAE: {np.mean(mae_scores):.4f}")
print(f"Overall mean MSE: {np.mean(mse_scores):.4f}")
# Save model & predictions (original scale)
model.save("models/ANN_improved_regressor.h5")
pd.DataFrame(y_pred, columns=y_te.columns).to_csv(
    "outputs/ANN_improved_predictions.csv", index=False
)
y_te.to_csv("outputs/ANN_improved_actuals.csv", index=False)
# Save ANN metrics for each target to CSV
ann_metrics = pd.DataFrame(
    {
        "Model": ["ANN"] * len(y_te.columns),
        "target": list(y_te.columns),
        "r2": r2_scores,
        "mae": mae_scores,
        "mse": mse_scores,
    }
)
ann_metrics.to_csv("outputs/ANN_improved_metrics.csv", index=False)
print("Saved improved model and predictions.")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 1s 90ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#       angle_mie: R²=0.9910, MAE=0.0954, MSE=0.0140
#      length_mie: R²=0.9924, MAE=3.3012, MSE=20.5885
#    angle_shadow: R²=0.9849, MAE=0.1192, MSE=0.0216
#   length_shadow: R²=0.9932, MAE=3.1945, MSE=20.0414
#
# Overall mean R²: 0.9904
# Overall mean MAE: 1.6776
# Overall mean MSE: 10.1664
#
# Saved improved model and predictions.
