# %%
# ─────────────────────────────────────────────────────────────
# Cell 1 ▸ Imports & global settings
# ─────────────────────────────────────────────────────────────
import os
import random
import warnings

# Set environment variables for determinism BEFORE importing TensorFlow
os.environ["TF_DETERMINISTIC_OPS"] = "1"
os.environ["PYTHONHASHSEED"] = "42"

import joblib
import keras
from keras import callbacks, layers, models
import numpy as np
import pandas as pd
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import tensorflow as tf

# Configuration
warnings.filterwarnings("ignore")
pd.set_option("display.precision", 4)

# Set random seeds for reproducibility
SEED = 42
random.seed(SEED)
np.random.seed(SEED)
tf.random.set_seed(SEED)

# Check TensorFlow setup
print("TensorFlow version:", tf.__version__)
print("Physical devices:", tf.config.list_physical_devices("GPU"))

# Create output folders
for folder in ["models", "outputs"]:
    os.makedirs(folder, exist_ok=True)
# Out:
# TensorFlow version: 2.20.0
# Physical devices: []

# %%
# ─────────────────────────────────────────────────────────────
#  Cell 2 ▸ Load & tidy the data
# ─────────────────────────────────────────────────────────────
csv_path = "data/processed/preprocessed_dataset.csv"

if not os.path.exists(csv_path):
    raise FileNotFoundError(
        f"Dataset not found at {csv_path}. Please run the data preprocessing pipeline first."
    )

raw = pd.read_csv(csv_path)

# Harmonise column names
rename_map = {
    "Time_ms": "time",
    "Pc_bar": "chamb_pressure",
    "Tc_K": "cham_temp",
    "Pinj_bar": "injection_pres",
    "rho_kgm3": "density",
    "mu_Pas": "viscosity",
    "angle_shadow_deg": "angle_shadow",
    "len_shadow_L_D": "length_shadow",
    "angle_mie_deg": "angle_mie",
    "len_mie_L_D": "length_mie",
}
df = raw.rename(columns=rename_map)

INPUTS = ["time", "chamb_pressure", "cham_temp", "injection_pres", "density", "viscosity"]
TARGETS = ["angle_mie", "length_mie", "angle_shadow", "length_shadow"]

print("Data shape  :", df.shape)
display(df.head())
# Out:
# Data shape  : (726, 11)
#       run   time  chamb_pressure  cham_temp  injection_pres   density  \
# 0  ETH-01  0.000         55.0318   192.0295         98.8645  810.7202
# 1  ETH-01  0.025         55.0057   192.0158         98.8741  810.7183
# 2  ETH-01  0.050         55.0081   191.9882         98.9074  810.7184
# 3  ETH-01  0.075         55.0164   192.0820         98.8550  810.7191
# 4  ETH-01  0.100         55.0125   191.9880         98.8788  810.7188
#
#    viscosity  angle_shadow  length_shadow  angle_mie  length_mie
# 0     0.0019       16.6945        13.1266    12.9373     17.5713
# 1     0.0019       16.6945        13.1266    12.9373     17.5713
# 2     0.0019       16.6945        13.1266    12.9373     17.5713
# 3     0.0019       16.6945        13.1266    12.9373     17.5713
# 4     0.0019       16.6945        20.2047    12.9373     24.5066

# %%
# ─────────────────────────────────────────────────────────────
#  Cell 3 ▸ Train-test split  (stratified by experimental run)
# ─────────────────────────────────────────────────────────────
X, y = df[INPUTS], df[TARGETS]
runs = df["run"]  # stratification label
X_tr, X_te, y_tr, y_te = train_test_split(X, y, test_size=0.20, random_state=42, stratify=runs)

print(f"Train: {X_tr.shape}   Test: {X_te.shape}")
# Out:
# Train: (580, 6)   Test: (146, 6)

# %%
# ─────────────────────────────────────────────────────────────
# Cell 4 ▸ Prepare scaled train and test data (reuse X_tr, y_tr, X_te, y_te)
# ─────────────────────────────────────────────────────────────
# Use the same train-test split as ML baselines (reuse your existing X_tr, y_tr, X_te, y_te)

# Scale input features
input_scaler = StandardScaler()
X_train_scaled = input_scaler.fit_transform(X_tr)
X_test_scaled = input_scaler.transform(X_te)

# Scale output targets
target_scaler = StandardScaler()
y_train_scaled = target_scaler.fit_transform(y_tr)
y_test_scaled = target_scaler.transform(y_te)

# Save scalers
joblib.dump(input_scaler, "models/ann_input_scaler.joblib")
joblib.dump(target_scaler, "models/ann_target_scaler.joblib")

print("Scaling completed. Shapes:", X_train_scaled.shape, y_train_scaled.shape)
# Out:
# Scaling completed. Shapes: (580, 6) (580, 4)

# %%
# ─────────────────────────────────────────────────────────────
# Cell 5 ▸ Build the ANN model architecture
# ─────────────────────────────────────────────────────────────
def build_deep_ann(input_dim, output_dim, seed=42):
    # Use HeNormal initializer for better convergence with ReLU
    initializer = keras.initializers.HeNormal(seed=seed)

    model = models.Sequential(
        [
            layers.InputLayer(input_shape=(input_dim,)),
            layers.Dense(256, activation="relu", kernel_initializer=initializer),  # type: ignore[reportArgumentType]
            layers.BatchNormalization(),
            layers.Dropout(0.4, seed=seed),
            layers.Dense(128, activation="relu", kernel_initializer=initializer),  # type: ignore[reportArgumentType]
            layers.BatchNormalization(),
            layers.Dropout(0.3, seed=seed),
            layers.Dense(64, activation="relu", kernel_initializer=initializer),  # type: ignore[reportArgumentType]
            layers.BatchNormalization(),
            layers.Dropout(0.2, seed=seed),
            layers.Dense(output_dim, activation="linear", kernel_initializer=initializer),  # type: ignore[reportArgumentType]
        ]
    )

    model.compile(optimizer="adam", loss="mse", metrics=["mae"])
    return model


model = build_deep_ann(X_train_scaled.shape[1], y_train_scaled.shape[1])
model.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense_4 (Dense)                 │ (None, 256)            │         1,792 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_6 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_7 (Dense)                 │ (None, 4)              │           260 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 44,996 (175.77 KB)
#  Trainable params: 44,100 (172.27 KB)
#  Non-trainable params: 896 (3.50 KB)

# %%
# ─────────────────────────────────────────────────────────────
# Cell 6 ▸ Train the ANN model with EarlyStopping
# ─────────────────────────────────────────────────────────────
early_stop = callbacks.EarlyStopping(monitor="val_loss", patience=30, restore_best_weights=True)
reduce_lr = callbacks.ReduceLROnPlateau(monitor="val_loss", factor=0.5, patience=10)

history = model.fit(
    X_train_scaled,
    y_train_scaled,
    validation_split=0.2,
    epochs=500,
    batch_size=32,
    callbacks=[early_stop, reduce_lr],
    verbose="2",
)
# Out:
# Epoch 1/500
# Epoch 2/500
# Epoch 2/500
# Epoch 3/500
# Epoch 3/500
# Epoch 4/500
# Epoch 4/500
# Epoch 5/500
# Epoch 5/500
# Epoch 6/500
# Epoch 6/500
# Epoch 7/500
# Epoch 7/500
# Epoch 8/500
# Epoch 8/500
# Epoch 9/500
# Epoch 9/500
# Epoch 10/500
# Epoch 10/500
# Epoch 11/500
# Epoch 11/500
# Epoch 12/500
# Epoch 12/500
# Epoch 13/500
# Epoch 13/500
# Epoch 14/500
# Epoch 14/500
# Epoch 15/500
# Epoch 15/500
# Epoch 16/500
# Epoch 16/500
# Epoch 17/500
# Epoch 17/500
# Epoch 18/500
# Epoch 18/500
# Epoch 19/500
# Epoch 19/500
# Epoch 20/500
# Epoch 20/500
# Epoch 21/500
# Epoch 21/500
# Epoch 22/500
# Epoch 22/500
# Epoch 23/500
# Epoch 23/500
# Epoch 24/500
# Epoch 24/500
# Epoch 25/500
# Epoch 25/500
# Epoch 26/500
# Epoch 26/500
# Epoch 27/500
# Epoch 27/500
# Epoch 28/500
# Epoch 28/500
# Epoch 29/500
# Epoch 29/500
# Epoch 30/500
# Epoch 30/500
# Epoch 31/500
# Epoch 110/500
# Epoch 111/500
# Epoch 111/500
# Epoch 112/500
# Epoch 112/500
# Epoch 113/500
# Epoch 113/500
# Epoch 114/500
# Epoch 114/500
# Epoch 115/500
# Epoch 115/500
# Epoch 116/500
# Epoch 116/500
# Epoch 117/500
# Epoch 117/500
# Epoch 118/500
# Epoch 118/500
# Epoch 119/500
# Epoch 119/500
# Epoch 120/500
# Epoch 120/500
# Epoch 121/500
# Epoch 121/500
# Epoch 122/500
# Epoch 122/500
# Epoch 123/500
# Epoch 123/500
# Epoch 124/500
# Epoch 124/500
# Epoch 125/500
# Epoch 125/500
# Epoch 126/500
# Epoch 126/500
# Epoch 127/500
# Epoch 127/500
# Epoch 128/500
# Epoch 128/500
# Epoch 129/500
# Epoch 129/500
# Epoch 130/500
# Epoch 130/500
# Epoch 131/500
# Epoch 131/500
# Epoch 132/500
# Epoch 132/500
# Epoch 133/500
# Epoch 133/500
# Epoch 134/500
# Epoch 134/500
# Epoch 135/500
# Epoch 135/500
# Epoch 136/500
# Epoch 136/500
# Epoch 137/500
# Epoch 137/500
# Epoch 138/500
# Epoch 138/500
# Epoch 139/500
# Epoch 139/500

# %%
# ─────────────────────────────────────────────────────────────
# Cell 7 ▸ Evaluate the ANN model on the test set
# ─────────────────────────────────────────────────────────────

# Inverse transform predictions & evaluate on original scale
y_pred_scaled = model.predict(X_test_scaled)
y_pred = target_scaler.inverse_transform(y_pred_scaled)

# Calculate metrics
metrics = {
    "r2": [r2_score(y_te[col], y_pred[:, i]) for i, col in enumerate(y_te.columns)],
    "mae": [mean_absolute_error(y_te[col], y_pred[:, i]) for i, col in enumerate(y_te.columns)],
    "mse": [mean_squared_error(y_te[col], y_pred[:, i]) for i, col in enumerate(y_te.columns)],
}

# Print per-target metrics
for i, col in enumerate(y_te.columns):
    print(
        f"{col:>15}: R²={metrics['r2'][i]:.4f}, MAE={metrics['mae'][i]:.4f}, MSE={metrics['mse'][i]:.4f}"
    )

print(f"\nOverall mean R²: {np.mean(metrics['r2']):.4f}")
print(f"Overall mean MAE: {np.mean(metrics['mae']):.4f}")
print(f"Overall mean MSE: {np.mean(metrics['mse']):.4f}")

# Save model & predictions (original scale)
model.save("models/ANN_improved_regressor.h5")
pd.DataFrame(y_pred, columns=y_te.columns).to_csv(
    "outputs/ANN_improved_predictions.csv", index=False
)
y_te.to_csv("outputs/ANN_improved_actuals.csv", index=False)

# Save ANN metrics for each target to CSV
ann_metrics = pd.DataFrame(
    {
        "Model": ["ANN"] * len(y_te.columns),
        "target": list(y_te.columns),
        "r2": metrics["r2"],
        "mae": metrics["mae"],
        "mse": metrics["mse"],
    }
)
ann_metrics.to_csv("outputs/ANN_improved_metrics.csv", index=False)
print("Saved improved model and predictions.")
# Out:
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# 5/5 ━━━━━━━━━━━━━━━━━━━━ 0s 35ms/step
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
#       angle_mie: R²=0.9902, MAE=0.0998, MSE=0.0153
#      length_mie: R²=0.9873, MAE=4.3103, MSE=34.6942
#    angle_shadow: R²=0.9755, MAE=0.1546, MSE=0.0350
#   length_shadow: R²=0.9883, MAE=4.3744, MSE=34.3610
#
# Overall mean R²: 0.9853
# Overall mean MAE: 2.2348
# Overall mean MSE: 17.2764
# Saved improved model and predictions.
